# %% [markdown]
# # string operator

# %%
name = 'Nithish kumar reddy'
name[5]
age='4'
name+' '+ age
# Out:
# 'Nithish kumar reddy 4'

# %%
name[0:6]
print(name[0:5:2])
print(name[0:8:1])
print(name[4])
print(name[3:])
print(name[:8])
print(name[::2])
print(name[-1])
print(name[-5:2])
print(name[-5:-8])
print(name[-8:-5])
# Out:
# Nti
# Nithish
# i
# hish kumar reddy
# Nithish
# Ntihkmrrdy
# y
#
#
# ar

# %%
name='apple'
print(name*5)
# Out:
# appleappleappleappleapple

# %%
print('apple\t'*5)
# Out:
# apple	apple	apple	apple	apple

# %%
print('apple\n'*5)
# Out:
# apple
# apple
# apple
# apple
# apple

# %%
name='Ammu'
name[0]
# Out:
# 'A'

# %%
name.index('m')
# Out:
# 1

# %%
len(name)
print(len(name))
print("name")
# Out:
# 4
# name

# %%
print(name+"  "+"raju")
# Out:
# Ammu  raju

# %%
name.upper()
# Out:
# 'AMMU'

# %%
name.lower()
# Out:
# 'ammu'

# %%
name.title()
# Out:
# 'Ammu'

# %%
location="  Bengalore"
#location.lstrip()
#location.rstrip()
location.strip()
# Out:
# 'Bengalore'
