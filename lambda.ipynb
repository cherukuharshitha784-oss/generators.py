# %%
J = [100,200,300,400,500,1000]
Discount=[]
for i in J:
    print(i*10/100)
    Discount=i*0.1
    print(Discount,'-Discount is :',i-Discount)
# Out:
# 10.0
# 10.0 -Discount is : 90.0
# 20.0
# 20.0 -Discount is : 180.0
# 30.0
# 30.0 -Discount is : 270.0
# 40.0
# 40.0 -Discount is : 360.0
# 50.0
# 50.0 -Discount is : 450.0
# 100.0
# 100.0 -Discount is : 900.0

# %%
J = [100,200,300,400,500,1000]
print(list(map(lambda i:i*0.1,J)))
# Out:
# [10.0, 20.0, 30.0, 40.0, 50.0, 100.0]

# %%
emails=["user@gmail.com","anu@gmail.com","Invalid","valid"]
if '@' in 'user@gmail.com':

    print('Algonex')
# Out:
# Algonex

# %%
emails=["user@gmail.com","anu@gmail.com","Invalid","valid"]
for i in range(len(emails)):
    if '@' in 'user@gmail.com':

     print('Algonex')
# Out:
# Algonex
# Algonex
# Algonex
# Algonex

# %%
emails=["anu@gmail.com","arya@gmail.com","ammu@gmail.com","prathi.com","Harshu.com"]
created_email=input("enter the new email")
for i in emails:
    if '@' in str(i):
       print(i)
    if created_email in emails:
        print("email already exists")
    else:
         emails.append(created_email)
else:
    print("Invalid emails")
# Out:
# anu@gmail.com
# arya@gmail.com
# email already exists
# ammu@gmail.com
# email already exists
# email already exists
# email already exists
# harshi@gamil.com
# email already exists
# Invalid emails
