# %%
def Algonex(Name = 'karuna'):
    print("Algonex is a software company")
    return("f{Name} worked at Algonex company")
Algonex("karuna")
# Out:
# Algonex is a software company
# 'f{Name} worked at Algonex company'

# %%
def user(a=10,b=20):
    return a+b, a-b, a*b, a/b, a//b, a**b
user(int(input("enter a value for a: ")),10)
# Out:
# (20, 0, 100, 1.0, 1, 10000000000)

# %%
def floor_div(a,b):
    return a//b
floor_div(10,3)
# Out:
# 3

# %%
add = lambda x,y,z: x+y-z
print(add(10,20,5))
# Out:
# 25

# %%
j=[100,200,300,400,500]
print(list(map(lambda x:x+10,j)))
# Out:
# [110, 210, 310, 410, 510]

# %%
emails=['user@gmail.com','anu@gmail.com','ammu@gmail.com','valid','invalid']
valid_emails=list(filter(lambda x:'@' in x , emails))
print(valid_emails)
# Out:
# ['user@gmail.com', 'anu@gmail.com', 'ammu@gmail.com']

# %%
transactions=[100,120,300,400,500]
monthly_total=0
for i in transactions:
    monthly_total+=i
print(monthly_total)
# Out:
# 1420

# %%
for i in range (1,11):
    if i==5:
        continue
    print(i**2)
# Out:
# 1
# 4
# 9
# 16
# 36
# 49
# 64
# 81
# 100

# %%
def total_salary(*args):
    print(args)
total_salary(1000,2000,3000,4000,5000)
def total_salary(*args):
    total=0
    for i in args:
        total+=i
    return total
# Out:
# (1000, 2000, 3000, 4000, 5000)

# %%
def total_salary(*args):
    print(*args)
    print(sum(args))
    print(max(args))
    print(min(args))
    print(len(args))
total_salary(1000,2000,3000,4000,5000)
# Out:
# 1000 2000 3000 4000 5000
# 15000
# 5000
# 1000
# 5

# %%
def employee(**kwargs):
    print(kwargs)
    print(type(kwargs))
    print(kwargs['name'])
    print(kwargs.values())
    print(kwargs.keys())
employee(name='karuna',age=22,designation='software developer')
# Out:
# {'name': 'karuna', 'age': 22, 'designation': 'software developer'}
# <class 'dict'>
# karuna
# dict_values(['karuna', 22, 'software developer'])
# dict_keys(['name', 'age', 'designation'])

# %%
def countdown(n):
    if n==0:
        return
    print(n)
    countdown(n-1)
countdown(5)
# Out:
# 5
# 4
# 3
# 2
# 1
