# %% [markdown]
# # set operations

# %%
skills=["python","java","SQL","C++"]
print(skills)
# Out:
# ['python', 'java', 'SQL', 'C++']

# %%
skills.remove("SQL")

# %%
skills.pop()
# Out:
# 'C++'

# %%
skills.clear()

# %%
a={1,2,3,4,5,6}
b={4,5,6,7,8,9}
print(a.union(b))
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8, 9}

# %%
a={1,2,3,4,5,6}
b={4,5,6,7,8,9}

print(a.intersection(b))
# Out:
# {4, 5, 6}

# %%
a={1,2,3,4,5,6}
b={4,5,6,3,2}
print(a-b)
print(b-a)
# Out:
# {1}
# set()
