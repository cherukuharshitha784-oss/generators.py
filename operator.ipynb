# %% [markdown]
# # operators

# %%
10+5
10-8
10*3
10/3
10//5
10%2
2**4
# Out:
# 16

# %%
CGPA = int(input("enter amigos"))
skills='python'
if CGPA >=7 and skills =='python':
    print('eligible')
# Out:
# eligible

# %%
count=5
count+=1
print(count)
# Out:
# 6

# %%
skills=['python','AI','sql','java']
if "python" in skills:
    print(skills)
# Out:
# ['python', 'AI', 'sql', 'java']

# %%
a=10
b=20
print(a is b)
# Out:
# False
