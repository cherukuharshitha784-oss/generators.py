# %% [markdown]
# # python basic rules

# %%
X = 10
Y = 20
print(X+Y)
# Out:
# 30

# %%
W = [1,2,3,4,5]
for i in W:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
V = 10
v = 20
print(V)
# Out:
# 10

# %%
v=10
if v==10:
    print("v is exactly 10")
    print("v")
    print(v)
# Out:
# v is exactly 10
# v
# 10

# %%
x = input ("Enter hurry kind of word")
if x in ['f','d','g','h']:
    print('x exist in list')
else:
    print('not exist')
# Out:
# x exist in list

# %%
name ='Algonex'
w = True
s =[10,'y','true',23]
print(s)
# Out:
# [10, 'y', 'true', 23]

# %%
a=50
type(a)
# Out:
# int

# %%
age=25
print(type(age))
print(type(int(age)))
# Out:
# <class 'int'>
# <class 'int'>
# <class 'int'>

# %%
name='HARSHITHA REDDY'
print(type(name))
# Out:
# <class 'str'>

# %%
pincode='560037'
print(type(pincode))
# Out:
# <class 'str'>

# %%
L="HARSHITHA CHERUKU"
L=L.split(" ")
print(L)
print(type(L))
L=list(L)
print(L)
# Out:
# ['HARSHITHA', 'CHERUKU']
# <class 'list'>
# ['HARSHITHA', 'CHERUKU']
